# %%
# Basic imporitng

from math import sqrt, pi
from math import *  # imports every function

# %%
print(sqrt(69))
print(pi)
# Out:
# 8.306623862918075
# 3.141592653589793

# %%
import numpy as np

# %%
from package.maths import addition
addition(56,76)

# importing a particular function from the same project
# always create a __init.py__ if you want to import a package in another folder as it transforms the folder into a package.
# Out:
# 132
